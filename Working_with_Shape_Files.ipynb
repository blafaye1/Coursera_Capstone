# %%
import pandas as pd

# %%
import geopandas as gpd

# %%
from bokeh.models import GeoJSONDataSource
from bokeh.plotting import figure, show

# %%
fname = '/Users/bridgettelafaye/Downloads/cb_2018_06_place_500k/cb_2018_06_place_500k.shp'
california = gpd.read_file(fname)
california.head()
# Out:
#   STATEFP PLACEFP   PLACENS          AFFGEOID    GEOID           NAME LSAD  \
# 0      06   46492  02411054  1600000US0646492  0646492        Maywood   25
# 1      06   17750  02410282  1600000US0617750  0617750        Cypress   25
# 2      06   56938  02411418  1600000US0656938  0656938       Piedmont   25
# 3      06   69088  02411819  1600000US0669088  0669088  Santa Clarita   25
# 4      06   13392  02409461  1600000US0613392  0613392    Chula Vista   25
#
#        ALAND   AWATER                                           geometry
# 0    3052102        0  POLYGON ((-118.20416 33.98952, -118.20433 33.9...
# 1   17127728    21850  POLYGON ((-118.06332 33.83153, -118.06123 33.8...
# 2    4402167        0  POLYGON ((-122.24930 37.82372, -122.24812 37.8...
# 3  170638259   162849  MULTIPOLYGON (((-118.56481 34.35969, -118.5591...
# 4  128547314  6380537  POLYGON ((-117.12399 32.64636, -117.11707 32.6...

# %%
california[california['NAME'] == 'San Francisco']
# Out:
#     STATEFP PLACEFP   PLACENS          AFFGEOID    GEOID           NAME LSAD  \
# 682      06   67000  02411786  1600000US0667000  0667000  San Francisco   25
#
#          ALAND     AWATER                                           geometry
# 682  121375681  479216672  MULTIPOLYGON (((-122.33205 37.78776, -122.3275...

# %%
california.iloc[682]['geometry']

# %%
fname = '/Users/bridgettelafaye/Downloads/cb_2018_17_place_500k/cb_2018_17_place_500k.shp'
illinois = gpd.read_file(fname)

# %%
illinois[illinois['NAME'] == 'Chicago']
# Out:
#     STATEFP PLACEFP   PLACENS          AFFGEOID    GEOID     NAME LSAD  \
# 463      17   14000  00428803  1600000US1714000  1714000  Chicago   25
#
#          ALAND    AWATER                                           geometry
# 463  588881101  17625494  POLYGON ((-87.94010 42.00093, -87.93501 42.001...

# %%
illinois.iloc[463]['geometry']

# %%
chicago = illinois.loc[463:463]

# %%
illinois.loc[463:463]
# Out:
#     STATEFP PLACEFP   PLACENS          AFFGEOID    GEOID     NAME LSAD  \
# 463      17   14000  00428803  1600000US1714000  1714000  Chicago   25
#
#          ALAND    AWATER                                           geometry
# 463  588881101  17625494  POLYGON ((-87.94010 42.00093, -87.93501 42.001...

# %%
fname = '/Users/bridgettelafaye/Downloads/cb_2018_36_place_500k/cb_2018_36_place_500k.shp'
new_york = gpd.read_file(fname)

# %%
new_york[new_york['NAME'] == 'New York']
# Out:
#    STATEFP PLACEFP   PLACENS          AFFGEOID    GEOID      NAME LSAD  \
# 85      36   51000  02395220  1600000US3651000  3651000  New York   25
#
#         ALAND     AWATER                                           geometry
# 85  777967926  434656806  MULTIPOLYGON (((-73.77336 40.85945, -73.77244 ...

# %%
new_york.iloc[85]['geometry']

# %%
geosource = GeoJSONDataSource(geojson = chicago.to_json())

# %%
p = figure()
p.patches('xs', 'ys', source = geosource)
show(p)
